# %% [markdown]
# We run the following Python script:
# ```python
# var = 3
# var = var + 5
# var = 2 * var + 1
# var = 1 - var
# ```
# ----
# 1.   Complete the table below, which shows the value contained in the variable var after executing each line of the script.
#
#
# | Line | Value |
# | ---- | ----- |
# | 1    |       |
# | 2    |       |
# | 3    |       |
# | 4    |       |
# ---
# 2.   What is the type of this variable: integer, floating-point number, or string?
